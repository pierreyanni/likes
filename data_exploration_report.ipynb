# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df = pd.read_csv('data/train.csv')
df.head()
# Out:
#                  Id     User Name                 Personal URL  \
# 0  AL85S14OMDPF01I9   Mf9vfld4Vfe                          NaN
# 1  HI11QOPD7BLJTO7Q  xl9gaGN0hxM_                          NaN
# 2  JS49LP5P72RI1OQB        d_uiMm                          NaN
# 3  S0GDSC09MACCLBJP       hfylaRr  https://blob/e/g9pex_vS.com
# 4  CRSEMK4QER6LDJSA    hRR1sDGlz5  https://blob/v/Szeo.h4/.com
#
#   Profile Cover Image Status Profile Verification Status Profile Text Color  \
# 0                        Set                    Verified             db1a2c
# 1                        Set                    Verified             0099cc
# 2                        Set                Not verified             1fc2de
# 3                    Not set                    Verified             050000
# 4                        Set                Not verified             58424d
#
#   Profile Page Color Profile Theme Color  Is Profile View Size Customized?  \
# 0             eaf0f2              e70409                             False
# 1             f6ffd1              fff04d                             False
# 2             efefef              1fc2de                             False
# 3             616161              00090a                             False
# 4             f7f7f7              000000                             False
#
#    UTC Offset                      Location Location Public Visibility  \
# 0     39600.0                           NaN                    Enabled
# 1         NaN                        mumbai                    Enabled
# 2    -18000.0  NYC + 70 Countries Worldwide                    Enabled
# 3    -14400.0              Indianapolis, In                    Enabled
# 4    -18000.0    777 Beach Blvd. Biloxi, MS                    Enabled
#
#   User Language      Profile Creation Timestamp              User Time Zone  \
# 0            en  Thu Nov 27 05:24:59 +0000 2008                      Sydney
# 1            en  Fri Jan 15 18:00:46 +0000 2010                         NaN
# 2            en  Fri Oct 02 20:15:06 +0000 2009  Central Time (US & Canada)
# 3            en  Thu Feb 19 14:37:22 +0000 2009  Eastern Time (US & Canada)
# 4            en  Tue Mar 31 13:27:52 +0000 2009  Central Time (US & Canada)
#
#    Num of Followers  Num of People Following  Num of Status Updates  \
# 0             95763                     4289                  30809
# 1           1018746                      289                   8150
# 2             13444                     1876                   4698
# 3            339168                     1148                  53216
# 4              9215                       93                   3271
#
#    Num of Direct Messages Profile Category  \
# 0                     873         business
# 1                     290          unknown
# 2                     227          unknown
# 3                    4035         business
# 4                     130          unknown
#
#    Avg Daily Profile Visit Duration in seconds  Avg Daily Profile Clicks  \
# 0                                       14.792                    1.5761
# 1                                        8.183                   11.2782
# 2                                       31.823                    0.5725
# 3                                       23.052                    4.0265
# 4                                        8.418                    3.9229
#
#           Profile Image  Num of Profile Likes
# 0  AL85S14OMDPF01I9.png                  2815
# 1  HI11QOPD7BLJTO7Q.png                  1242
# 2  JS49LP5P72RI1OQB.png                  1559
# 3  S0GDSC09MACCLBJP.png                  6342
# 4  CRSEMK4QER6LDJSA.png                  1078

# %% [markdown]
# # Modify features

# %%
# target in log
df['log Num of Profile Likes'] = np.log1p(df['Num of Profile Likes'])

# transform utc offset:
df['Sin_UTC'] = np.sin((11 * 3600 + df['UTC Offset']) / (24 * 3600) * 2 * np.pi)
df['Cos_UTC'] = np.cos((11 * 3600 + df['UTC Offset']) / (24 * 3600) * 2 * np.pi)

# time since creation in days
duration = (pd.to_datetime('today') - 
            pd.to_datetime(df['Profile Creation Timestamp']).dt.tz_localize(None))
df['Duration'] = duration.apply(lambda x: x.days)


# merge categories names with and without cap letter
df['Location Public Visibility'] = df['Location Public Visibility'].apply(lambda x: x.lower())

# convert personal url into True/False (NaNs or unique)
df['Has Personal URL'] = df['Personal URL'].notna()

# %% [markdown]
# ## Comments about some features
#
# The following variables should not be included in the regressions:
#
# * Id, User Name, Profile Image: unique for each users
# * Personal URL: replaced by Has Personal URL (True/False)
# * UTC Offset: replaced by sin_UTC and cos_UTC
# * Profile Creation Timestamp: replaced by Duration
# * Num of Profiles Likes+: was created just for the plots (but Num of Profiles Likes should be adjusted if taken in logs)
#
# Some missing values of UTC Offset could be obtained from Location (see below).

# %%
pd.crosstab(df['UTC Offset'].notna(), df['Location'].notna(), margins=True)
# Out:
# Location    False  True   All
# UTC Offset
# False         204   282   486
# True         1257  5757  7014
# All          1461  6039  7500

# %% [markdown]
# # Exploring the data
#
# * Target
# * Numerical features
# * Categorical features with few categories
# * Categorical features with lots of categories

# %%
# target

def plot_log(feature, save=False):

    fig, ax = plt.subplots(1, 2, figsize=(12, 4))

    ax[0].hist(df[feature], density=True, bins=100)
    ax[0].set_title(feature)

    ax[1].hist(np.log1p(df[feature]), density=True, bins=100)
    ax[1].set_title(f'Log {feature}')
    if save:
        plt.savefig('figures/' + save + '.png', dpi=300)
    plt.show()
    
plot_log('Num of Profile Likes', 'profile_likes')

# %%
# target

def plot_log_vertical(feature, save=False):

    fig, ax = plt.subplots(2, 1, figsize=(8, 10))

    ax[0].hist(df[feature], density=True, bins=100)
    ax[0].set_ylabel('probability density')
    ax[0].set_title(feature)

    ax[1].hist(np.log1p(df[feature]), density=True, bins=100)
    ax[1].set_ylabel('probability density')
    ax[1].set_title(f'Log {feature}')
    plt.tight_layout()
    if save:
        plt.savefig('figures/' + save + '.png', dpi=300)
    plt.show()
    
plot_log_vertical('Num of Profile Likes', 'profile_likes')

# %%
for feature in ['Num of Followers', 'Num of People Following',
                'Num of Status Updates', 'Num of Direct Messages',
                'Avg Daily Profile Visit Duration in seconds',
                'Avg Daily Profile Clicks']:
    plot_log(feature)

# %%
np.corrcoef(df[f'log_{feature}'],  df['log Num of Profile Likes'])[0, 1]
# Out:
# 0.11230981188393149

# %%
# numerical features

def plot(feature, alpha=0.1, log=True, xlim=None, xscale=None, save=False):
    if log:
        df[f'log_{feature}'] = df[feature].apply(np.log1p)
        plt.scatter(df[f'log_{feature}'], df['log Num of Profile Likes'], alpha=alpha)
        plt.xlabel(f'log {feature}')
    else:
        plt.scatter(df[feature], df['log Num of Profile Likes'], alpha=alpha)
        plt.xlabel(f'log {feature}')
    plt.ylabel('log Num of Profile Likes')
    
    if xlim is not None:
        plt.xlim(xlim)
    if xscale is not None:
        plt.xscale(xscale)
    
    if save:
        plt.savefig('figures/' + save + '.png', dpi=300)
    plt.show()
    
    corr = np.round(np.corrcoef(df[f'log_{feature}'],  df['log Num of Profile Likes'])[0, 1], 2)
    print(f'correlation: {corr}')
    
    if xlim is not None:
        perc_obs = df[feature].between(xlim[0], xlim[1]).sum() / df[feature].notna().sum()
    else:
        perc_obs = 1
    print(f'percentage of observations in plot: {np.round(100*perc_obs, 1)}%')
    
    
plot('Num of Followers')
plot('Num of People Following')
plot('Num of Status Updates', save='status_update')
plot('Num of Direct Messages')
plot('Avg Daily Profile Visit Duration in seconds')
plot('Avg Daily Profile Clicks')
plot('Sin_UTC', alpha=0.05)
plot('Cos_UTC', alpha=0.05)
plot('Duration')
# Out:
# correlation: 0.11
# percentage of observations in plot: 100%
# correlation: 0.42
# percentage of observations in plot: 100%
# correlation: 0.4
# percentage of observations in plot: 100%
# correlation: 0.17
# percentage of observations in plot: 100%
# correlation: nan
# percentage of observations in plot: 100%
# correlation: nan
# percentage of observations in plot: 100%
# correlation: nan
# percentage of observations in plot: 100%
# correlation: nan
# percentage of observations in plot: 100%
# correlation: 0.16
# percentage of observations in plot: 100%

# %%
# small number of categories

def show_categories(feature, save=False):
    print(f'\n{feature.upper()}:')
    sns.displot(df, x='log Num of Profile Likes', hue=feature, 
            kind='kde', common_norm=False, fill=True)
    if save:
        plt.savefig('figures/' + save + '.png', dpi=300) 
    plt.show()
    display(df.groupby(df[feature], dropna=False)['log Num of Profile Likes'].describe())
    
for feature in ['Has Personal URL', 'Profile Cover Image Status',
                'Profile Verification Status', 
                'Is Profile View Size Customized?', 
                'Location Public Visibility', 'Profile Category']:
    show_categories(feature)
# Out:
# HAS PERSONAL URL:
#                    count      mean       std  min       25%       50%  \
# Has Personal URL
# False             4244.0  7.840617  1.910678  0.0  7.199678  8.051660
# True              3256.0  5.156593  2.510062  0.0  3.784190  5.463832
#
#                        75%        max
# Has Personal URL
# False             8.952540  13.025835
# True              6.463029  13.218755
# PROFILE COVER IMAGE STATUS:
#                              count      mean       std  min       25%  \
# Profile Cover Image Status
# Not set                     1691.0  6.982899  2.381051  0.0  5.973810
# Set                         5719.0  6.588954  2.605455  0.0  5.153292
# NaN                           90.0  6.390356  2.730335  0.0  5.212116
#
#                                  50%       75%        max
# Profile Cover Image Status
# Not set                     7.451242  8.604651  12.972119
# Set                         7.149917  8.450840  13.218755
# NaN                         6.939851  8.372341  11.420064
# PROFILE VERIFICATION STATUS:
#                               count      mean       std  min       25%  \
# Profile Verification Status
# Not verified                 2146.0  5.999016  2.615851  0.0  4.524491
# Pending                       583.0  5.950570  2.583416  0.0  4.510618
# Verified                     4771.0  7.068198  2.452259  0.0  5.874931
#
#                                   50%       75%        max
# Profile Verification Status
# Not verified                 6.473886  7.857287  12.736798
# Pending                      6.541030  7.818227  12.063575
# Verified                     7.596894  8.755028  13.218755
# IS PROFILE VIEW SIZE CUSTOMIZED?:
#                                    count      mean       std  min       25%  \
# Is Profile View Size Customized?
# False                             6785.0  6.803226  2.505665  0.0  5.545177
# True                               715.0  5.462314  2.779316  0.0  3.663562
#
#                                        50%       75%        max
# Is Profile View Size Customized?
# False                             7.330405  8.550241  13.218755
# True                              5.805135  7.633370  12.063575
# LOCATION PUBLIC VISIBILITY:
#                              count      mean       std  min       25%  \
# Location Public Visibility
# ??                           372.0  6.959449  2.389019  0.0  5.754950
# disabled                    2773.0  5.679374  2.837389  0.0  3.970292
# enabled                     4355.0  7.285333  2.166444  0.0  6.242221
#
#                                  50%       75%        max
# Location Public Visibility
# ??                          7.395699  8.640163  12.063575
# disabled                    6.142037  7.805475  13.025835
# enabled                     7.678326  8.751395  13.218755
# PROFILE CATEGORY:
#                    count      mean       std  min       25%       50%  \
# Profile Category
#                    240.0  6.836923  2.261024  0.0  5.840526  7.188790
# business          1839.0  7.304510  2.482292  0.0  6.108135  7.794823
# celebrity         1401.0  7.399291  2.354773  0.0  6.276643  7.945910
# government         660.0  7.098324  2.406681  0.0  5.906721  7.633612
# unknown           3360.0  5.934610  2.542493  0.0  4.543295  6.467699
#
#                        75%        max
# Profile Category
#                   8.390199  11.616456
# business          9.028279  13.025835
# celebrity         8.992806  12.183960
# government        8.727483  11.734299
# unknown           7.790386  13.218755

# %%
# lots of categories: need to aggregate

def agg_categories(feature, min_size=100):
    val_counts = df[feature].fillna('nan').value_counts()
    l_others = val_counts[val_counts < min_size].index.unique().tolist()
    df[f'Cat {feature}'] = df[feature].fillna('nan').replace(to_replace=l_others,
                                               value='others')
   
for feature in ['Profile Text Color', 'Profile Page Color',
                'Profile Theme Color', 'User Language', 'Location',
                'User Time Zone']:
    agg_categories(feature)
    show_categories(f'Cat {feature}')
    
agg_categories('User Language')
show_categories('Cat User Language', save='user_language')
# Out:
# CAT PROFILE TEXT COLOR:
#                          count      mean       std  min       25%       50%  \
# Cat Profile Text Color
# 000000                   162.0  6.946645  2.750212  0.0  5.794533  7.500916
# 0084b4                  1284.0  6.212986  2.702512  0.0  4.675089  6.760372
# 009999                   386.0  6.620968  2.580341  0.0  5.088855  7.098367
# 1b95e0                   146.0  6.987016  2.447956  0.0  5.720846  7.273857
# 1da1f2                   709.0  5.459272  2.787482  0.0  3.663562  5.802118
# 2fc2ef                   134.0  6.728577  2.550774  0.0  5.173224  7.358455
# 3b94d9                   171.0  7.053411  2.313985  0.0  5.951936  7.461640
# abb8c2                   151.0  7.029694  2.155536  0.0  5.652335  7.623153
# dd2e44                   102.0  7.342051  1.901335  0.0  6.056718  7.577811
# ff0000                   118.0  6.186441  2.949213  0.0  4.632220  6.626608
# others                  4137.0  6.978017  2.411245  0.0  5.857933  7.465655
#
#                              75%        max
# Cat Profile Text Color
# 000000                  8.764866  12.736798
# 0084b4                  8.142205  13.025835
# 009999                  8.416652  11.462453
# 1b95e0                  8.539571  12.972119
# 1da1f2                  7.656810  12.063575
# 2fc2ef                  8.408470  11.650624
# 3b94d9                  8.625868  11.900790
# abb8c2                  8.545094  10.886689
# dd2e44                  8.674448  11.068012
# ff0000                  8.602699  11.243254
